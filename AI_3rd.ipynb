# %% [markdown]
# FILE HANDLING AND EXCEPTIONS
#
# OPENING AND READING A FILE

# %%
#using open() function with "r" mode to open and read a file
f =open("Sample.txt","r")
print(f.read())
#A good practice to close a file with close() method/function
f.close()
# Out:
# Hi my name is Sajina

# %%
f=open("Sample.txt","r")
print(f.readline())
print(f.readline())

f.close()
# Out:
# Hi my name is Sajina
#
# hello

# %%
f=open("Sample.txt","r")
print(f.read(8))
f.close()
# Out:
# Python i

# %% [markdown]
# WITH OPERATION

# %%
with open("new.txt","r")as file:
  print (file.read())
# Out:
# I am created 5 seconds then
#  I am appned now!

# %% [markdown]
# WRITING TO A FILE

# %%
#EXISTING FILE
f=open("Sample.txt","w")
f.write("Python is great for AI",)
f.close()

# %%
#NON EXISTING FILE
f=open("new.txt","w")
f.write("I am created 5 seconds then")
f.close()

# %% [markdown]
# APPNENDING TO A FILE

# %%
f=open("new.txt","a")
#/n is used to print the content in the next line
f.write("\n I am appened now!")
f.close()

# %% [markdown]
# DELETING A FILE

# %%
#importing OS module
import os
os.remove("Sample.txt")

# %%
import os
os.rmdir("/content/delete_me")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-f972b8aa3938> in <cell line: 0>()
#       1 import os
# ----> 2 os.rmdir("/content/delete_me")
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/delete_me'

# %% [markdown]
# BASIC EXCEPTIONS HANDLING

# %%
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-bca0e2660b9f> in <cell line: 0>()
# ----> 1 print(a)
#
# NameError: name 'a' is not defined

# %%
try:
  print(a)
except:
    print("An error occured")
# Out:
# An error occured

# %%
a=5
try:
  print(a)
except NameError:
  print("Variable a is not defined")

except TypeError:
  print("An error occured")
# Out:
# 5

# %% [markdown]
# CLASSWORK

# %% [markdown]
# Write a short message to a file and verify the content by opening it in a text editor.

# %%
f= open("hello.txt","w")
print(f.write("Good morning"))
f.close()
# Out:
# 12

# %% [markdown]
# Append your name and favorite programming language to an existing file.

# %%
f=open("hello.txt","a")
f.write("\n Sajina\n Python programming language")
f.close()

# %% [markdown]
# Open a file using "with", read all lines, and count how many lines it has.

# %%
with open("hello.txt","r") as f:
 a=f.readlines()
 print(a)
 print(len(a))
# Out:
# ['Good morning\n', ' Sajina\n', ' Python programming language\n', ' Sajina\n', ' Python programming language\n', ' Sajina\n', ' Python programming language']
# 7

# %% [markdown]
# Write a program that takes two numbers and handles division safely using 'try-except'.

# %%
a=2
b=0
try:
  print(a/b)
except ZeroDivisionError:
  print("cannot be divided by zero")
finally:
  print("execution completed")
# Out:
# cannot be divided by zero
# execution completed

# %%
try:
 a= int(input("Enter first number:"))
 b= int(input("Enter second number:"))
 print(a/b)
except ZeroDivisionError:
  print("cannot ne divided by zero")
finally:
  print("execution completed")
# Out:
# Enter a number:1
# Enter a number:2
# 0.5
# execution completed

# %% [markdown]
# HOMEWORK

# %% [markdown]
# Copying a file with error hamndling

# %%
try:
    with open("input.txt", "r") as f:
        a = f.read()
    with open("output.txt", "w") as file:
        file.write(a)
except FileNotFoundError:
    print("File does not exist")
finally:
    print("executed successfully")
# Out:
# File does not exist
# executed successfully

# %%
try:
    with open("data.txt", "r") as f:
       c = len(f.readlines())
    if c == 0:
        print("The file is empty")
    else:
        print("The total line count is",c)

    with open("line_count.txt", "w") as file:
        file.write(str(c))

except FileNotFoundError:
    print("The file 'data.txt' doesnot exist")
finally :
    print("Executed successfully")
# Out:
# The file 'data.txt' doesnot exist
# Executed successfully
