# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3],[4,5,6])
plt.title("Simple line plot")
plt.show()

# %% [markdown]
# PANDAS AND MATPLOTLIB
#
# pandas series:1d ARRAY WITH LABELS

# %%
#importing pandas library
import pandas as pd

#Creating a series with .series method/function and printing the series
scores = pd.Series([67,89,12,45],index=['Aarav','Bina','Cindrella','diana'])
print(scores)
# Out:
# Aarav        67
# Bina         89
# Cindrella    12
# diana        45
# dtype: int64

# %% [markdown]
# Task 1: Create a Pandas series with values [10, 20, 30, 40] and indices ["A", "B", "C", "D"]. Print the series.

# %%
#Creating a series with .series method/function and printing the series
scores=pd.Series([10,20,30,40],index= ["A", "B", "C", "D"] )
print(scores)
# Out:
# A    10
# B    20
# C    30
# D    40
# dtype: int64

# %% [markdown]
# # Task 2: Create a dataframe with columns "City" (["Paris", "Tokyo", "Sydney"]) and "Population" ([2.1, 37.4, 5.3]). Print the dataframe.

# %%
data ={"City":['Paris','Tokyo','Syndey'],
       "Population":[2.1,37.4,5.3]
       }
df = pd.DataFrame(data)
print(df)
# Out:
#      City  Population
# 0   Paris         2.1
# 1   Tokyo        37.4
# 2  Syndey         5.3

# %% [markdown]
# Exercise 2:Creating a pandas dataframe
#
#
# Dataframe is in a table format

# %%
data ={"Name":['A','B','C'],
       "Age":[12,14,16],
       "Score":[34,56,26]
       }
df = pd.DataFrame(data)
print(df)
# Out:
#   Name  Age  Score
# 0    A   12     34
# 1    B   14     56
# 2    C   16     26

# %% [markdown]
# #EXERCISE 3:FILTERING DATA IN DATAFRAME

# %%
data ={
    'Name':('Asmita','Binod','Chandra','Dipendra'),
    'Class':[9,9,9,10],
    'Subject':['Math','Science','English','Nepali']
}
df =pd.DataFrame(data)
print(df_new)

#Filtering the dataframe
filter =df[df['Class']>9]
print(filter)
# Out:
#        Name  Class  Subject
# 0    Asmita      9     Math
# 1     Binod      9  Science
# 2   Chandra      9  English
# 3  Dipendra     10   Nepali
#        Name  Class Subject
# 3  Dipendra     10  Nepali

# %% [markdown]
# #TASK 3:CREATE A DATAFRAME WITH COLUMNS "NAME"(("EVE",""

# %% [markdown]
# EXERCISE 4:READING AND PROCESSING A CSV FILE

# %%
import io

#Creating a CSV file
csv_data ="""Name,Grade
Arpan,89
Rupesh,68
Sabina,67
"""

#Reading a CSV file
df=pd.read_csv(io.StringIO(csv_data))
print(df)

#Calculate average grade
average_grade=df['Grade'].mean()
print(f'  Average Grade:{average_grade}')

#Calculate Max grade
max_grade=df['Grade'].max()
print(f'Max Grade:{max_grade}')
# Out:
#      Name  Grade
# 0   Arpan     89
# 1  Rupesh     68
# 2  Sabina     67
#   Average Grade:74.66666666666667
# Max Grade:89
